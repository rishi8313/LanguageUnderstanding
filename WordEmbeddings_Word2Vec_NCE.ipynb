# %% [markdown]
# ## Generate word2vec embeddings using TensorFlow
#
# Use Noise Contrastive Estimator (NCE) as a loss function
#
# Modified from original code here: http://adventuresinmachinelearning.com/word2vec-tutorial-tensorflow/

# %% [markdown]
# #### Some imports to make code compatible with Python 2 as well as 3

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
import collections
import math
import os
import random
import zipfile

# %%
from six.moves import urllib
from six.moves import xrange

# %%
import numpy as np
import tensorflow as tf

# %%
print(np.__version__)
print(tf.__version__)
# Out:
# 1.13.1
# 1.3.0

# %%
DOWNLOADED_FILENAME = 'SampleText.zip'

def maybe_download(url_path, expected_bytes):
    if not os.path.exists(DOWNLOADED_FILENAME):
        filename, _ = urllib.request.urlretrieve(url_path, DOWNLOADED_FILENAME)
    statinfo = os.stat(DOWNLOADED_FILENAME)

    if statinfo.st_size == expected_bytes:
        print('Found and verified file from this path: ', url_path)
        print('Downloaded file: ', DOWNLOADED_FILENAME)
    else:
        print(statinfo.st_size)

        raise Exception(
            'Failed to verify file from: ' + url_path + '. Can you get to it with a browser?')

# %%
def read_words():
    with zipfile.ZipFile(DOWNLOADED_FILENAME) as f:
        firstfile = f.namelist()[0]
        filestring = tf.compat.as_str(f.read(firstfile))
        words = filestring.split()
    
    return words

# %%
URL_PATH = 'http://mattmahoney.net/dc/text8.zip'
FILESIZE = 31344016

maybe_download(URL_PATH, FILESIZE)
# Out:
# Found and verified file from this path:  http://mattmahoney.net/dc/text8.zip
# Downloaded file:  SampleText.zip

# %% [markdown]
# #### Get the list of words from the the sample, this is our entire vocabulary

# %%
vocabulary = read_words()

# %%
len(vocabulary)
# Out:
# 17005207

# %%
vocabulary[:25]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes']

# %% [markdown]
# ### Build the data set used to generate word2vec embeddings
#
# * *words* A list of all words in the input dataset
# * *n_words* The number of words to include in the dataset. We use the most frequently occurring n_words
#
# Return values are:
#
# * *word_counts* The most frequently occurring words and the corresponding frequencies
# * *word_indexes* The list of index values which uniquely identifies each word in the dataset
# * *dictionary* Mapping from a word to its unique index
# * *reversed_dictionary* Mapping from the unique index to the word

# %%
def build_dataset(words, n_words):
    word_counts = [['UNKNOWN', -1]]
    
    counter = collections.Counter(words)
    word_counts.extend(counter.most_common(n_words - 1))
 
    # Only the most common words are added to the dictionary
    dictionary = dict()
    
    for word, _ in word_counts:
        # The current length of the dictionary is the unique index of this word
        # added to the dictionary
        dictionary[word] = len(dictionary)
    
    word_indexes = list()
    
    unknown_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNKNOWN']
            unknown_count += 1
        
        word_indexes.append(index)
    
    # Count of unknown words
    word_counts[0][1] = unknown_count
    
    # Map from unique indexes to word
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    
    return  word_counts, word_indexes, dictionary, reversed_dictionary

# %%
VOCABULARY_SIZE = 100000

word_counts, word_indexes, dictionary, reversed_dictionary = build_dataset(vocabulary, VOCABULARY_SIZE)

# %%
word_counts[:10]
# Out:
# [['UNKNOWN', 189230],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430)]

# %%
word_indexes[:10]
# Out:
# [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
for key in random.sample(list(dictionary), 10):
    print(key, ":", dictionary[key])
# Out:
# hrerbunker : 54289
# ethicists : 43633
# refits : 75611
# inmarsat : 18736
# impracticable : 87209
# elitists : 82373
# vz : 79055
# kota : 48526
# hanse : 31849
# anonymous : 6412

# %%
for key in random.sample(list(reversed_dictionary), 10):
    print(key, ":", reversed_dictionary[key])
# Out:
# 43127 : warps
# 95758 : xero
# 60708 : wadb
# 98901 : rothrock
# 30757 : grooming
# 35425 : wattle
# 20184 : curing
# 53621 : mukhabarat
# 12957 : warlord
# 63097 : fsn

# %% [markdown]
# ### Return one batch of data and the corresponding labels for training
#
# * *word_indexes* A list of unique indexes which identifies each word in the dataset. The most popular words have the lowest index values
# * *batch_size* The number of elements in each batch
# * *num_skips* The number of words to choose from the neighboring words within the skip_window. Each input word will appear num_skips times in the batch with a context or neighboring word as the corresponding label
# * *skip_window* How many words to consider around one input word

# %%
# Global index into words maintained across batches
global_index = 0

def generate_batch(word_indexes, batch_size, num_skips, skip_window):
    global global_index

    # For every input we find num_skips context words within a window
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    
    # batch = [1, 2, 3, .... batch_size]
    # labels = [[1], [2], [3], ..., [batch_size]]
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    # The span of a window includes the skip_window elements on each side
    # of the input word plus the word itself
    span = 2 * skip_window + 1  # [ skip_window input_word skip_window ]

    # A deque is double-ended queue which supports memory efficient appends
    # and pops from each side
    buffer = collections.deque(maxlen=span)

    # Initialize the deque with the first words in the deque
    for _ in range(span):
        buffer.append(word_indexes[global_index])
        global_index = (global_index + 1) % len(word_indexes)
    
    for i in range(batch_size // num_skips):
        target = skip_window  # input word at the center of the buffer
        targets_to_avoid = [skip_window]

        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            
            batch[i * num_skips + j] = buffer[skip_window]  # this is the input word
            labels[i * num_skips + j, 0] = buffer[target]  # these are the context words
        
        # The first word from the buffer is removed automatically when a new word
        # is added in at the end
        buffer.append(word_indexes[global_index])
        global_index = (global_index + 1) % len(word_indexes)
    
    # Backtrack a little bit to avoid skipping words in the end of a batch, these
    # words will be captured in the next batch
    global_index = (global_index + len(word_indexes) - span) % len(word_indexes)

    return batch, labels

# %%
batch, labels = generate_batch(word_indexes, 10, 2, 5)

# %%
batch
# Out:
# array([   2,    2, 3134, 3134,   46,   46,   59,   59,  156,  156])

# %%
labels
# Out:
# array([[3081],
#        [  59],
#        [   2],
#        [ 156],
#        [   6],
#        [ 128],
#        [ 156],
#        [  46],
#        [  59],
#        [ 742]])

# %%
for i in range(9):
    print(reversed_dictionary[batch[i]], ": ", reversed_dictionary[labels[i][0]])
# Out:
# of :  originated
# of :  used
# abuse :  of
# abuse :  against
# first :  a
# first :  early
# used :  against
# used :  first
# against :  used

# %% [markdown]
# ### Initialize some variables to build and train the skip-gram model
#
# * *batch_size*: The size of the batch to use in training
# * *embedding_size*: Dimensions of the embedding vector i.e. how many features we use to represent a word
# * *skip_window*: How many words to include in the context, this is to the left and right
# * *num_skips*: How many context words to associate with each target word

# %%
batch_size = 128
embedding_size = 50
skip_window = 2
num_skips = 2

# Reset the global index because we updated while testing the batch code
global_index = 0

# %% [markdown]
# ### Choose some words at random to validate our trained model
#
# * *valid_size*: Number of words to evaluate our model, we'll use these words to see how similar the closest words are
# * *valid_window*: The window from where we draw the words to run validation on, only pick from the most commonly used words
#
# Choose the set of words from the top 100 at random

# %%
valid_size = 16  
valid_window = 100

valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %% [markdown]
# ### Number of negative examples to sample for NCE loss calculation

# %%
num_samples = 64

# %% [markdown]
# ### Input placeholder to feed data in batches

# %%
tf.reset_default_graph()

train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])

# %% [markdown]
# ### Set up a constant to hold validation data

# %%
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %% [markdown]
# ### Embeddings are word representations that will be generated by word2vec
#
# Initialize a variable to hold the embeddings and embeddings for specific words can be accessed using *tf.nn.embedding_lookup*
#
# NOTE: Embeddings and NCE losses only work on the CPU in TensorFlow, GPU support has not been added yet

# %%
embeddings = tf.Variable(
    tf.random_uniform([VOCABULARY_SIZE, embedding_size], -1.0, 1.0))
embed = tf.nn.embedding_lookup(embeddings, train_inputs)

# %% [markdown]
# ### Construct weights and biases to hold the NCE (Noise Contrastive Estimation) loss

# %%
nce_weights = tf.Variable(
    tf.truncated_normal([VOCABULARY_SIZE, embedding_size],
                        stddev=1.0 / math.sqrt(embedding_size)))
nce_biases = tf.Variable(tf.zeros([VOCABULARY_SIZE]))

# %%
loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_samples,
                     num_classes=VOCABULARY_SIZE))

# %%
 optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

# %% [markdown]
# ### Normalize the embeddings vector to calculate cosine similarity between words
#
# *normalized_vector = vector / L2 norm of vector*

# %%
l2_norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / l2_norm

# %% [markdown]
# #### Look up the normalized embeddings of the words we use to validate our model

# %%
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)

# %% [markdown]
# #### Find the cosine similarity of the validation words against all words in our vocabulary

# %%
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
init = tf.global_variables_initializer()

# %%
num_steps = 200001

# %%
final_embeddings = None

with tf.Session() as session:
    init.run()

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            word_indexes, batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 20000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reversed_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reversed_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
            print("\n")
            
    final_embeddings = normalized_embeddings.eval()
# Out:
# Average loss at step  0 :  301.796142578
# Nearest to who: tipping, supersonics, monroe, sinuous, bunten, cairo, vara, toolbars,
# Nearest to the: moragas, eurasians, mendeleev, adys, crystallized, corrupted, ambuscades, encephalopathy,
# Nearest to will: magister, solicitation, kaifu, odwigowo, inuits, anat, hammersley, practical,
# Nearest to over: pris, pedrolino, flocked, itv, climatic, ladislaus, ral, keyesville,
# Nearest to is: roles, biscayne, teltow, wollongong, asq, prospero, tauris, intel,
# Nearest to d: facilitated, obywatelska, amontillado, retail, cafe, ripe, huari, orla,
# Nearest to are: pablo, clemson, ultimate, azov, neo, minarets, epicurean, communitarian,
# Nearest to see: willard, rags, wilfrid, prez, dubbings, fringe, papillon, protected,
# Nearest to such: optimized, amplitude, absorbed, babbage, jotuns, nestled, texts, sulphate,
# Nearest to i: byggdist, romain, einbecker, omnisexual, preliminary, shakhbut, sinnott, umayyad,
# Nearest to new: bucking, utulei, parceled, leopardi, irritation, krb, britney, kotorska,
# Nearest to during: mika, shroud, ascensius, sappho, crosser, clytemnestra, exams, vials,
# Nearest to seven: sirens, nin, generalises, morisco, estimated, petiole, congratulated, isotope,
# Nearest to years: erlbaum, circularly, curvilinear, corresponding, dramatization, identified, apricots, shou,
# Nearest to first: mcvay, bayerische, halitosis, marxism, danica, mchenry, richly, ubiquitin,
# Nearest to six: paulista, creston, treble, luge, biskup, shoots, ecr, sabatini,
#
#
# Average loss at step  2000 :  148.731974674
# Average loss at step  4000 :  86.2532064571
# Average loss at step  6000 :  62.7857514296
# Average loss at step  8000 :  48.214708024
# Average loss at step  10000 :  39.8816530168
# Average loss at step  12000 :  32.6139265406
# Average loss at step  14000 :  27.8999488604
# Average loss at step  16000 :  23.3876588449
# Average loss at step  18000 :  20.3815071871
# Average loss at step  20000 :  17.7180738988
# Nearest to who: molecules, however, that, by, magnus, circ, amoeba, madeira,
# Nearest to the: a, an, or, its, and, this, their, these,
# Nearest to will: combined, portrayal, magister, much, degree, it, he, quezon,
# Nearest to over: in, grandmother, cake, metre, five, array, cambridge, agouti,
# Nearest to is: was, are, tt, substances, has, crossing, operatorname, through,
# Nearest to d: ripe, novella, collaborative, jewellery, surviving, b, retail, quality,
# Nearest to are: were, is, but, before, was, guthrum, eckenstein, apus,
# Nearest to see: mass, union, willard, leon, modes, published, appointed, which,
# Nearest to such: vast, amplitude, well, compulsive, harmless, girl, defence, homosexuals,
# Nearest to i: sarah, some, antilles, tested, and, around, tourist, moxibustion,
# Nearest to new: commanded, ladder, approved, irritation, argo, recorder, demon, sayers,
# Nearest to during: warnings, friars, colleagues, headache, argo, steam, win, weary,
# Nearest to seven: four, three, six, nine, zero, five, eight, agouti,
# Nearest to years: shaw, circ, macbook, agouti, corresponding, nine, ethidium, acapulco,
# Nearest to first: elegant, dorset, rudimentary, athena, circ, logical, richly, pneumonia,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
#
#
# Average loss at step  22000 :  15.3963976399
# Average loss at step  24000 :  14.2566170667
# Average loss at step  26000 :  13.6188411975
# Average loss at step  28000 :  12.3494727483
# Average loss at step  30000 :  11.5715057765
# Average loss at step  32000 :  10.7073042364
# Average loss at step  34000 :  9.58874278247
# Average loss at step  36000 :  9.53746766496
# Average loss at step  38000 :  8.85635072756
# Average loss at step  40000 :  8.23452031064
# Nearest to who: however, that, he, which, molecules, magnus, by, tav,
# Nearest to the: its, a, their, an, dasyprocta, pataphysics, aveiro, agouti,
# Nearest to will: would, bpp, combined, can, acornsoft, may, that, when,
# Nearest to over: in, grandmother, from, array, at, circ, aryans, cake,
# Nearest to is: was, are, were, tt, through, has, mctaggart, tight,
# Nearest to d: b, UNKNOWN, sarajevo, novella, collaborative, misrepresented, ripe, rang,
# Nearest to are: were, is, but, recycling, guthrum, was, cdp, calming,
# Nearest to see: mass, published, willard, belinda, appointed, union, leon, modes,
# Nearest to such: well, vast, amplitude, sulphate, unreasonable, harmless, pursues, compulsive,
# Nearest to i: some, occupational, sarah, bauxite, frost, surgery, around, and,
# Nearest to new: approved, commanded, ladder, gdr, britney, irritation, argo, sayers,
# Nearest to during: colleagues, weary, friars, in, warnings, dahr, on, at,
# Nearest to seven: six, four, eight, three, five, nine, one, zero,
# Nearest to years: handicraft, shaw, macbook, sapkowski, oilers, acapulco, help, tdma,
# Nearest to first: dorset, richly, sponsors, circ, pneumonia, elegant, friedrichsfelde, education,
# Nearest to six: five, three, seven, four, eight, one, zero, nine,
#
#
# Average loss at step  42000 :  8.34158606839
# Average loss at step  44000 :  7.50642209768
# Average loss at step  46000 :  7.55652126384
# Average loss at step  48000 :  7.56399641347
# Average loss at step  50000 :  6.9592671591
# Average loss at step  52000 :  7.02628868759
# Average loss at step  54000 :  7.25741514874
# Average loss at step  56000 :  6.77826940727
# Average loss at step  58000 :  6.74168746412
# Average loss at step  60000 :  6.52903307438
# Nearest to who: however, he, by, which, sarajevo, magnus, that, molecules,
# Nearest to the: its, their, an, a, his, each, dasyprocta, all,
# Nearest to will: would, can, may, bpp, could, to, when, but,
# Nearest to over: in, michelob, until, at, array, circ, when, eax,
# Nearest to is: was, are, wct, michelob, hipper, has, seceded, became,
# Nearest to d: b, sarajevo, novella, UNKNOWN, misrepresented, ripe, collaborative, rang,
# Nearest to are: were, is, or, recycling, precipitated, calming, condensate, alban,
# Nearest to see: mass, published, belinda, willard, waas, cpa, sd, dhamma,
# Nearest to such: well, vast, known, budd, as, sulphate, amplitude, occupations,
# Nearest to i: occupational, bauxite, m, solomon, avail, sarah, some, sarajevo,
# Nearest to new: ladder, gdr, approved, irritation, balochistan, commanded, argo, britney,
# Nearest to during: in, at, colleagues, gravitationally, friars, weary, morita, over,
# Nearest to seven: six, eight, four, five, three, nine, zero, ursus,
# Nearest to years: handicraft, shaw, macbook, silence, help, elevator, oilers, michigan,
# Nearest to first: sponsors, circ, bonasus, maritimequest, michelob, bank, dasyprocta, bayerische,
# Nearest to six: eight, seven, four, five, three, nine, agouti, zero,
#
#
# Average loss at step  62000 :  6.59475411391
# Average loss at step  64000 :  6.25112019414
# Average loss at step  66000 :  5.99170001924
# Average loss at step  68000 :  6.51628265381
# Average loss at step  70000 :  6.30754524183
# Average loss at step  72000 :  6.03969095564
# Average loss at step  74000 :  6.01782061279
# Average loss at step  76000 :  5.92003237593
# Average loss at step  78000 :  6.20763138199
# Average loss at step  80000 :  6.26251246977
# Nearest to who: he, by, however, which, then, sarajevo, tele, they,
# Nearest to the: its, their, a, ascorbate, dasyprocta, kf, each, all,
# Nearest to will: would, can, may, could, to, must, bpp, when,
# Nearest to over: when, until, before, michelob, array, jubilees, at, during,
# Nearest to is: was, arenas, are, djinn, became, iie, collectivists, cry,
# Nearest to d: b, sarajevo, novella, r, ripe, m, collaborative, misrepresented,
# Nearest to are: were, precipitated, recycling, is, alban, carabiners, calming, guthrum,
# Nearest to see: mass, published, cpa, willard, belinda, waas, copyleft, moss,
# Nearest to such: well, known, budd, tetrahedra, dist, synapomorphy, occupations, natus,
# Nearest to i: m, bauxite, sarajevo, ii, ayling, occupational, avail, novella,
# Nearest to new: approved, gdr, balochistan, irritation, ladder, commanded, sovereignty, adequately,
# Nearest to during: in, at, gravitationally, over, weary, coro, morita, saguinus,
# Nearest to seven: eight, six, five, four, nine, three, one, zero,
# Nearest to years: silence, handicraft, macbook, shaw, xoring, yucatan, elevator, help,
# Nearest to first: maritimequest, sponsors, bank, circ, michelob, bonasus, amalthea, name,
# Nearest to six: seven, four, five, eight, three, nine, one, two,
# Average loss at step  82000 :  6.09433858883
# Average loss at step  84000 :  5.89167889607
# Average loss at step  86000 :  5.98344822586
# Average loss at step  88000 :  5.94875478196
# Average loss at step  90000 :  5.87125689161
# Average loss at step  92000 :  5.57331951463
# Average loss at step  94000 :  5.86200480795
# Average loss at step  96000 :  5.74657913148
# Average loss at step  98000 :  5.51388713944
# Average loss at step  100000 :  5.84326822495
# Nearest to who: he, by, tele, once, and, then, which, specified,
# Nearest to the: its, a, their, another, this, dasyprocta, any, each,
# Nearest to will: would, can, may, could, must, to, bpp, when,
# Nearest to over: before, when, until, jubilees, during, since, hikari, but,
# Nearest to is: was, are, lissodelphis, arenas, became, wct, tight, has,
# Nearest to d: b, sarajevo, m, r, UNKNOWN, novella, c, collaborative,
# Nearest to are: were, is, lissodelphis, recycling, precipitated, many, carabiners, calming,
# Nearest to see: cpa, mass, willard, bisons, belinda, waas, dhamma, moss,
# Nearest to such: well, known, budd, occupations, natus, tetrahedra, dist, semiarid,
# Nearest to i: ii, m, then, occupational, ayling, bauxite, sarajevo, you,
# Nearest to new: gdr, stitch, approved, adequately, balochistan, sovereignty, irritation, ladder,
# Nearest to during: in, over, at, morita, coro, weary, until, gravitationally,
# Nearest to seven: eight, six, five, four, three, nine, zero, agouti,
# Nearest to years: macbook, silence, xoring, shaw, handicraft, elevator, yucatan, sayer,
# Nearest to first: circ, michelob, sponsors, final, amalthea, maritimequest, bank, name,
# Nearest to six: seven, eight, five, four, three, nine, agouti, zero,
#
#
# Average loss at step  102000 :  5.67258903182
# Average loss at step  104000 :  5.70323997951
# Average loss at step  106000 :  5.71245970225
# Average loss at step  108000 :  5.65696563041
# Average loss at step  110000 :  5.6154651202
# Average loss at step  112000 :  5.57643441498
# Average loss at step  114000 :  5.43068892121
# Average loss at step  116000 :  5.39335519576
# Average loss at step  118000 :  5.52908834875
# Average loss at step  120000 :  5.47451479816
# Nearest to who: once, he, tele, by, which, never, then, sarajevo,
# Nearest to the: its, each, another, this, a, their, kf, dasyprocta,
# Nearest to will: would, may, could, must, can, to, might, should,
# Nearest to over: before, when, jubilees, however, since, hikari, eurocents, during,
# Nearest to is: was, became, arenas, are, seceded, olcott, toontown, lissodelphis,
# Nearest to d: b, sarajevo, novella, c, m, UNKNOWN, r, alert,
# Nearest to are: were, precipitated, lissodelphis, is, recycling, calming, stretching, many,
# Nearest to see: cpa, bisons, willard, waas, mass, haeckel, dhamma, arion,
# Nearest to such: well, budd, known, tetrahedra, occupations, dist, guillaume, natus,
# Nearest to i: then, g, m, you, ayling, novella, bauxite, ii,
# Nearest to new: approved, stitch, adequately, gdr, city, balochistan, sovereignty, brandeis,
# Nearest to during: over, in, coro, until, after, morita, keepalive, before,
# Nearest to seven: eight, six, four, five, three, nine, agouti, ursus,
# Nearest to years: macbook, xoring, silence, shaw, vandross, handicraft, elevator, acidosis,
# Nearest to first: final, bank, michelob, sponsors, circ, eurocents, state, name,
# Nearest to six: seven, five, eight, four, three, nine, agouti, zero,
#
#
# Average loss at step  122000 :  5.43680226004
# Average loss at step  124000 :  5.45379685426
# Average loss at step  126000 :  5.44657781446
# Average loss at step  128000 :  5.46742164278
# Average loss at step  130000 :  5.53050332129
# Average loss at step  132000 :  5.41074354589
# Average loss at step  134000 :  5.3745274632
# Average loss at step  136000 :  5.39306235182
# Average loss at step  138000 :  5.3152729286
# Average loss at step  140000 :  5.32446071613
# Nearest to who: once, he, tele, specified, successors, widtsoe, never, then,
# Nearest to the: its, another, each, any, a, nessus, their, kf,
# Nearest to will: would, could, may, can, must, might, to, should,
# Nearest to over: before, within, when, since, jubilees, however, around, during,
# Nearest to is: was, became, iie, arenas, lissodelphis, are, toontown, seceded,
# Nearest to d: b, singer, alert, c, UNKNOWN, microbats, novella, rang,
# Nearest to are: were, lissodelphis, precipitated, is, many, recycling, include, carabiners,
# Nearest to see: cpa, bisons, somethin, moss, sd, willard, epr, haeckel,
# Nearest to such: well, budd, known, tetrahedra, dist, ash, occupations, semiarid,
# Nearest to i: you, g, ii, ayling, then, extremophilic, m, hra,
# Nearest to new: city, adequately, stitch, crystals, topological, gdr, rampling, balochistan,
# Nearest to during: in, until, over, after, before, coro, keepalive, morita,
# Nearest to seven: eight, six, five, four, three, nine, agouti, ursus,
# Nearest to years: macbook, xoring, silence, binoche, elevator, vandross, reflexive, ewe,
# Nearest to first: final, original, last, second, name, michelob, eurocents, sponsors,
# Nearest to six: five, seven, four, eight, three, nine, agouti, zero,
#
#
# Average loss at step  142000 :  5.61459137261
# Average loss at step  144000 :  5.26527166891
# Average loss at step  146000 :  5.26037273037
# Average loss at step  148000 :  5.23003187251
# Average loss at step  150000 :  5.16032260048
# Average loss at step  152000 :  5.144736848
# Average loss at step  154000 :  5.24629141298
# Average loss at step  156000 :  5.31208448923
# Average loss at step  158000 :  5.2301891464
# Average loss at step  160000 :  5.27270937371
# Nearest to who: he, widtsoe, tele, once, specified, sweetheart, originally, never,
# Nearest to the: its, another, each, any, a, aquilegia, pataphysics, this,
# Nearest to will: would, could, may, can, must, might, should, to,
# Nearest to over: before, within, around, when, however, during, off, since,
# Nearest to is: was, became, are, arenas, olcott, iie, lissodelphis, toontown,
# Nearest to d: b, r, m, UNKNOWN, c, alert, n, sarajevo,
# Nearest to are: were, is, include, lissodelphis, precipitated, alban, recycling, carabiners,
# Nearest to see: cpa, moss, bisons, includes, epr, somethin, celebrities, arion,
# Nearest to such: well, known, result, budd, semiarid, tetrahedra, dist, hurry,
# Nearest to i: you, we, ii, then, extremophilic, ayling, g, hra,
# Nearest to new: city, adequately, stitch, rampling, crystals, gdr, sovereignty, balochistan,
# Nearest to during: after, in, before, over, until, coro, following, when,
# Nearest to seven: eight, six, five, four, three, nine, zero, agouti,
# Nearest to years: days, macbook, xoring, vandross, sayer, indigo, silence, webb,
# Nearest to first: final, original, last, second, dpi, eurocents, michelob, eax,
# Nearest to six: seven, four, five, eight, three, nine, zero, agouti,
#
#
# Average loss at step  162000 :  5.2871493119
# Average loss at step  164000 :  5.17721531153
# Average loss at step  166000 :  5.03342547083
# Average loss at step  168000 :  5.146927248
# Average loss at step  170000 :  5.12854214323
# Average loss at step  172000 :  5.1313033123
# Average loss at step  174000 :  5.12352012539
# Average loss at step  176000 :  5.12093196309
# Average loss at step  178000 :  5.0914499445
# Average loss at step  180000 :  5.178387007
# Nearest to who: widtsoe, tele, then, triumphantly, legs, he, gaba, successors,
# Nearest to the: its, each, any, a, another, dasyprocta, kf, aveiro,
# Nearest to will: would, could, must, can, may, might, should, cannot,
# Nearest to over: within, during, before, off, around, friars, through, following,
# Nearest to is: was, are, arenas, lissodelphis, iie, olcott, became, djinn,
# Nearest to d: b, r, m, c, novella, n, k, sarajevo,
# Nearest to are: were, is, precipitated, lissodelphis, include, carabiners, recycling, alban,
# Nearest to see: includes, cpa, bisons, catalana, haeckel, doll, moss, references,
# Nearest to such: well, known, ash, budd, dist, tetrahedra, defensa, natus,
# Nearest to i: you, ii, extremophilic, we, then, hra, ayling, wehrmacht,
# Nearest to new: adequately, city, stitch, third, sovereignty, brit, prorogation, residenz,
# Nearest to during: over, before, until, after, coro, in, following, around,
# Nearest to seven: six, eight, four, five, three, nine, zero, landesverband,
# Nearest to years: days, macbook, xoring, evian, indigo, akio, elevator, times,
# Nearest to first: final, last, original, second, third, dpi, michelob, landesverband,
# Nearest to six: seven, four, eight, five, three, nine, zero, two,
# Average loss at step  182000 :  5.05409136069
# Average loss at step  184000 :  5.17323086524
# Average loss at step  186000 :  4.97159124434
# Average loss at step  188000 :  5.05711169076
# Average loss at step  190000 :  5.09927805686
# Average loss at step  192000 :  5.11655152345
# Average loss at step  194000 :  5.09037402523
# Average loss at step  196000 :  5.0096207509
# Average loss at step  198000 :  5.02500193095
# Average loss at step  200000 :  4.86157756913
# Nearest to who: widtsoe, tele, gaba, legs, he, never, successors, kadi,
# Nearest to the: another, a, aum, its, dasyprocta, flageolet, leofa, each,
# Nearest to will: would, could, must, may, can, might, should, cannot,
# Nearest to over: around, within, off, during, before, out, following, through,
# Nearest to is: was, became, iie, arenas, are, toontown, olcott, seceded,
# Nearest to d: b, c, singer, rang, r, alert, novella, writer,
# Nearest to are: were, include, is, precipitated, lissodelphis, many, recycling, musket,
# Nearest to see: includes, references, catalana, dhamma, epr, cpa, doll, haeckel,
# Nearest to such: well, known, ash, budd, semiarid, tetrahedra, natus, xico,
# Nearest to i: you, ii, we, then, t, g, ayling, almagest,
# Nearest to new: adequately, city, stitch, sovereignty, third, childlike, deletes, residenz,
# Nearest to during: before, over, in, until, coro, after, around, following,
# Nearest to seven: eight, six, five, four, three, nine, landesverband, agouti,
# Nearest to years: days, macbook, akio, evian, xoring, hundred, indigo, leuciscus,
# Nearest to first: final, last, second, third, original, following, dpi, michelob,
# Nearest to six: seven, five, four, three, eight, landesverband, agouti, hyi,

# %%
def save_words_embeddings(embeddings, word_counts):
    
    np.save('embeddings.npy', embeddings)
    
    words = [x[0] for x in word_counts]
    np.save('words.npy', words)
    
save_words_embeddings(final_embeddings, word_counts)

# %% [markdown]
# ### Visualize the embeddings

# %%
import matplotlib.pyplot as plt

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'

    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)

        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)
    plt.show(filename)

# %%
from sklearn.manifold import TSNE
NUM_PLOT_POINTS = 500

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')

low_dim_embs = tsne.fit_transform(final_embeddings[:NUM_PLOT_POINTS, :])

labels = [reversed_dictionary[i] for i in xrange(NUM_PLOT_POINTS)]

# %%
plot_with_labels(low_dim_embs, labels)
